# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser
from itertools import chain
from urllib import request
import pandas as pd
import numpy as np
import json
import os

# %%
IS_JUPYTER = True
ROOT_PATH  = '/home/jovyan/project' if IS_JUPYTER else '/config/workspace/project'

JSON_PATH        = f'{ROOT_PATH}/utils/keys'
JSON_BACKUP_PATH = f'{ROOT_PATH}/BACKUPS/keys'

# %%
load_json = lambda json_path: json.loads(open(json_path, 'r').read())
save_json = lambda data, json_path: json.dump(data, open(json_path, 'w').write())

def repair_keys(json_path):
    try: keys = load_json(f'{json_path}/keys.json')
        
    except Exception as e:
        print(f'[ERR.K-002] json 파일이 깨져 열 수 없습니다. {e}')
        text = open(f'{JSON_BACKUP_PATH}/keys.txt', 'r').read().split('\n')
        keys = {platform : key 
                for platform, key in zip(['youtube', 'steam'], text)}
        
        save_paths = [JSON_PATH, JSON_BACKUP_PATH]
        for save_path in save_paths:
            os.makedirs(save_path, exist_ok = True)
            save_json(keys, f'{save_path}/keys.json')
        
    finally: return keys



if os.path.isfile(f'{JSON_PATH}/keys.json'):
    keys = repair_keys(JSON_PATH)
        
else:
    print(f'[ERR.K-001] json 파일이 존재하지 않아 백업 데이터를 로딩합니다.')
    keys = repair_keys(JSON_BACKUP_PATH)

# %%
## youtube api 사용할 수 있게 해주는 함수
def use_api():
    ## 개인 youtube api키 받고 사용하기 
    API_KEY          = keys['youtube']
    API_SERVICE_NAME = 'youtube'
    API_VERSION      = 'v3'
    
    return build(API_SERVICE_NAME, API_VERSION, developerKey = API_KEY)

# %%
from pprint import pprint

## 채널부터 시작해 영상 목록까지 가져오는 함수
def search_datas(query, max_result = 30):
    youtube = use_api()
    
    ## query에 해당하는 채널 이름 찾기
    ## max_result의 갯수 만큼 채널을 찾아 가져옴.
    result  = youtube.search().list(
                q          = query,
                part       = 'snippet',
                maxResults = max_result
            ).execute()
    
    ## youtube api에서 가져온 데이터가 json 데이터에 좀 복잡한 구조로 되어있는데,
    ## 채널 id는 channel_id 변수처럼 가져올 수 있다.
    channel_id = result['items'][0]['id']['channelId']
    
    ## 채널 내 플레이리스트 id 목록 가져옴.
    playlists  = search_playlists(youtube, channel_id)
    
    ## 영상 업로드 날짜, 제목, id, 썸네일 링크를 저장
    dates, titles, ids, thumbnails = [], [], [], []
    for playlist in playlists: 
        (d, t, i, th) = search_videos(youtube, playlist)
        dates      = list(chain(dates    , d))
        titles     = list(chain(titles   , t))
        ids        = list(chain(ids      , i))
        thumbnails = list(chain(thumbnails, th))
    
    ## 저장한 영상정보 데이터를 DataFrame으로 변환
    df         = pd.DataFrame([dates, titles, ids, thumbnails]).T
    df.columns = ['dates', 'titles', 'ids', 'thumbnails']
    return df
    
##채널 내 플레이리스트의 id 가져오는 함수
def search_playlists(youtube, id, max_result = 100):
    ## channelId에 해당하는 플레이리스트 찾기
    ## max_result의 갯수 만큼의 플레이리스트를 찾아 가져옴.
    result = youtube.playlists().list(
                channelId  = id,
                part       = 'snippet',
                maxResults = max_result
            ).execute()
    
    ## 플레이리스트 id 저장 
    ids = []
    for playlist in result['items']: 
        title = playlist['snippet']['localized']['title']
        if '2022년 침착맨 정주행' in title: ids.append(playlist['id'])
    return ids

## 채널의 플레이리스트에 있는 영상 정보 가져오는 함수
def search_videos(youtube, id, max_result = 200):
    ## playlistId에 해당하는 영상 찾기
    ## max_result의 갯수 만큼 영상을 찾아 가져옴.
    result = youtube.playlistItems().list(
                playlistId = id,
                part       = 'snippet',
                maxResults = max_result
            ).execute()
    titles, ids, thumbnails, dates = [], [], [],[]
    
    for video in result['items']:
        snippet = video['snippet']
        
        ## 비공개 동영상인 경우에 그냥 넘기기 
        if 'private' in snippet['title'].lower(): continue
        
        titles.append(snippet['title'])
        ids.append(snippet['resourceId']['videoId'])
        dates.append(snippet['publishedAt'])
        
        ## 썸네일에 medium 이미지가 없는 경우 default 이미지로 가져오기
        try: thumbnails.append(snippet['thumbnails']['medium']['url'])
        except: thumbnails.append(snippet['thumbnails']['default']['url'])
        
    return (dates, titles, ids, thumbnails)

# %%
df = search_datas('침착맨', max_result = 1)

# %%
df
# Out:
#                    dates                                    titles  \
# 0   2022-05-22T12:56:52Z                  환타로 만든 뱅쇼 vs 쌍화탕으로 만든 모주
# 1   2022-05-22T12:56:52Z                   2021년은 어땠나? 2022년은 어떨까?
# 2   2022-05-22T12:56:52Z                                 치킨계의 냉전시대
# 3   2022-05-22T12:56:52Z                           90년대 애니 여캐 둘러보기
# 4   2022-05-22T12:56:52Z                                 저가요 거위인데요
# 5   2022-05-22T12:56:52Z                            꽁치가처넌의 멸망의 노래!
# 6   2022-05-22T12:56:52Z               침착맨과 인기웹툰 '나 혼자만 레벨업' 같이 보기
# 7   2022-05-22T12:56:52Z                             맞기 싫은 몽둥이 월드컵
# 8   2022-05-22T12:56:52Z                      새해 금연합니다, 현상금 1000만원
# 9   2022-05-22T12:56:52Z                             특이한 벌레와 새 이야기
# 10  2022-05-22T12:56:52Z                                 오랜만에 버거형제
# 11  2022-05-22T12:56:52Z                             최고의 겨울 간식 월드컵
# 12  2022-05-22T12:56:52Z                           포켓몬의 미싱링크를 그려보자
# 13  2022-05-22T12:56:52Z                            신생대(新生代)를 알아보자
# 14  2022-05-22T12:56:52Z                      2021 침투부상 트로피 직접 만들기
# 15  2022-05-22T12:56:52Z                              나라가 허락한 대마커피
# 16  2022-05-22T12:56:52Z             '히어로의 과학' 특강 | 제1부 2021년의 히어로
# 17  2022-05-22T12:56:52Z                         전무아저씨와 도시락 먹으며 잡담
# 18  2022-05-22T12:56:52Z         '히어로의 과학' 특강 | 제2부 하루종일 설명할 수도 있어
# 19  2022-05-22T12:56:52Z                       맵크나이트의 엄청 매운 킹뚜껑 먹방
# 20  2022-05-22T12:56:52Z                        전 직장에 놀러가면 안 되는 이유
# 21  2022-05-22T12:56:52Z                   다낳대 야구선수 vs 스트리머 LoL 대회
# 22  2022-05-22T12:56:52Z                            더 놀라운 이왜진? 월드컵
# 23  2022-05-22T12:56:52Z  🎙️침터뷰 | 카더가든 편 - 말하는 걸 보면 노래가 상상이 안되는 가수
# 24  2022-05-22T12:56:52Z                         삼괴권(三壞拳)의 고수를 찾아서
# 25  2022-05-22T12:56:52Z                          칭찬양파 vs 비난양파 키우기
# 26  2022-05-22T12:56:52Z                   원피스 '밀짚모자 일당' NEW 구조조정안
# 27  2022-05-22T12:56:52Z       오다 선생님도 틀릴 거 같은 '원피스 3회 지식왕 결정전' 퀴즈
# 28  2022-05-22T12:56:52Z                        침착맨 주호민과 느껴보는 적벽대전
# 29  2022-05-22T12:56:52Z                       일하면서 침투부 보면 안 되는 이유
# 30  2022-05-22T12:56:52Z                               명절에 늦게 온 통천
# 31  2022-05-22T12:56:52Z                         비버니가 한 번 더 진화한다면?
# 32  2022-05-22T12:56:52Z                         맨유 팬에게 축구선수 카드 팔기
# 33  2022-05-22T12:56:52Z                        금연 23일차에 하는 담배 월드컵
# 34  2022-05-22T12:56:52Z               2022 설맞이 내기 윷놀이 ~커피부터 한우까지~
# 35  2022-05-22T12:56:52Z                  5초 안에 연상되는 3단어를 말하는 보드게임
# 36  2022-05-22T12:56:52Z                            포켓몬은 도구인가 친구인가
# 37  2022-05-22T12:56:52Z                          맵크나이트의 킹뚜껑 2차 도전
# 38  2022-05-22T12:56:52Z                          시청자가 묻고 침착맨이 답한다
# 39  2022-05-22T12:56:52Z                              원펀데이 간접체험 게임
# 40  2022-05-22T12:56:52Z                           단어를 맞혀 구미호를 찾아라
# 41  2022-05-22T12:56:52Z                           만화게임북 '고기동 大탈출'
# 42  2022-05-22T12:56:52Z                       7년 동안 침투부는 얼마나 성장했나
# 43  2022-05-22T12:56:52Z                          노딱 설명회는 노딱을 받을까?
# 44  2022-05-22T12:56:52Z                               침착맨 팬아트 감상회
# 45  2022-05-22T12:56:52Z                              40대 아저씨들의 내기
# 46  2022-05-22T12:56:52Z                        침&펄과 무신사 봄 신상 입어보기
# 47  2022-05-22T12:56:52Z                              옛날 로봇이 좋은 이유
# 48  2022-05-22T12:56:52Z                           괴상한 코믹스 캐릭터 월드컵
# 49  2022-05-22T12:56:52Z                    대콩절 기념 최고의 2인자 월드컵 제1부
#
#             ids                                        thumbnails
# 0   0pw5gBIAWQM  https://i.ytimg.com/vi/0pw5gBIAWQM/mqdefault.jpg
# 1   rwYoIzl5o9U  https://i.ytimg.com/vi/rwYoIzl5o9U/mqdefault.jpg
# 2   -YZ_z_TRBnY  https://i.ytimg.com/vi/-YZ_z_TRBnY/mqdefault.jpg
# 3   IcTjuJGoPbQ  https://i.ytimg.com/vi/IcTjuJGoPbQ/mqdefault.jpg
# 4   bDKA_p8jhSw  https://i.ytimg.com/vi/bDKA_p8jhSw/mqdefault.jpg
# 5   qMc79yi2N4A  https://i.ytimg.com/vi/qMc79yi2N4A/mqdefault.jpg
# 6   Z__KMr6QLEQ  https://i.ytimg.com/vi/Z__KMr6QLEQ/mqdefault.jpg
# 7   V0pNWjWlazo  https://i.ytimg.com/vi/V0pNWjWlazo/mqdefault.jpg
# 8   yJI9iCKlD9A  https://i.ytimg.com/vi/yJI9iCKlD9A/mqdefault.jpg
# 9   5T_4pnS6nxA  https://i.ytimg.com/vi/5T_4pnS6nxA/mqdefault.jpg
# 10  vm0O-Hpjs4g  https://i.ytimg.com/vi/vm0O-Hpjs4g/mqdefault.jpg
# 11  leOZrOGHj6U  https://i.ytimg.com/vi/leOZrOGHj6U/mqdefault.jpg
# 12  g9lOemftn5g  https://i.ytimg.com/vi/g9lOemftn5g/mqdefault.jpg
# 13  gsCrrBZQFqU  https://i.ytimg.com/vi/gsCrrBZQFqU/mqdefault.jpg
# 14  9X6U1rT9A8I  https://i.ytimg.com/vi/9X6U1rT9A8I/mqdefault.jpg
# 15  AOr439f6bJU  https://i.ytimg.com/vi/AOr439f6bJU/mqdefault.jpg
# 16  AsdHKLOM8uQ  https://i.ytimg.com/vi/AsdHKLOM8uQ/mqdefault.jpg
# 17  jQTkB4d_wms  https://i.ytimg.com/vi/jQTkB4d_wms/mqdefault.jpg
# 18  cmPAz7k3njs  https://i.ytimg.com/vi/cmPAz7k3njs/mqdefault.jpg
# 19  dz3lctZkn9o  https://i.ytimg.com/vi/dz3lctZkn9o/mqdefault.jpg
# 20  VLtv7n38xi4  https://i.ytimg.com/vi/VLtv7n38xi4/mqdefault.jpg
# 21  m3RvsWliS3w  https://i.ytimg.com/vi/m3RvsWliS3w/mqdefault.jpg
# 22  kOl27s1mgrg  https://i.ytimg.com/vi/kOl27s1mgrg/mqdefault.jpg
# 23  viPb0y86E4w  https://i.ytimg.com/vi/viPb0y86E4w/mqdefault.jpg
# 24  uKej8YD7Rlg  https://i.ytimg.com/vi/uKej8YD7Rlg/mqdefault.jpg
# 25  4t6x8M4bBvU  https://i.ytimg.com/vi/4t6x8M4bBvU/mqdefault.jpg
# 26  HlsL7Aw0ez4  https://i.ytimg.com/vi/HlsL7Aw0ez4/mqdefault.jpg
# 27  4-koqJzCpwY  https://i.ytimg.com/vi/4-koqJzCpwY/mqdefault.jpg
# 28  9h7AeWCBhtQ  https://i.ytimg.com/vi/9h7AeWCBhtQ/mqdefault.jpg
# 29  kDHSEDAfwL8  https://i.ytimg.com/vi/kDHSEDAfwL8/mqdefault.jpg
# 30  -dlJP9QTWAM  https://i.ytimg.com/vi/-dlJP9QTWAM/mqdefault.jpg
# 31  1cS4UvhLxwU  https://i.ytimg.com/vi/1cS4UvhLxwU/mqdefault.jpg
# 32  VQsu6Xr25R8  https://i.ytimg.com/vi/VQsu6Xr25R8/mqdefault.jpg
# 33  hVE_Qc6PjoA  https://i.ytimg.com/vi/hVE_Qc6PjoA/mqdefault.jpg
# 34  AiiRy_6iVB4  https://i.ytimg.com/vi/AiiRy_6iVB4/mqdefault.jpg
# 35  86h0qmq28ec  https://i.ytimg.com/vi/86h0qmq28ec/mqdefault.jpg
# 36  aCwk7SgIJ2U  https://i.ytimg.com/vi/aCwk7SgIJ2U/mqdefault.jpg
# 37  qXvzGDzMqKU  https://i.ytimg.com/vi/qXvzGDzMqKU/mqdefault.jpg
# 38  s3LBApU5Brg  https://i.ytimg.com/vi/s3LBApU5Brg/mqdefault.jpg
# 39  jia05SIv73M  https://i.ytimg.com/vi/jia05SIv73M/mqdefault.jpg
# 40  MjT31FNnc8I  https://i.ytimg.com/vi/MjT31FNnc8I/mqdefault.jpg
# 41  WXA1kDzhRw0  https://i.ytimg.com/vi/WXA1kDzhRw0/mqdefault.jpg
# 42  rSKfIJx79Pw  https://i.ytimg.com/vi/rSKfIJx79Pw/mqdefault.jpg
# 43  jPGDLCWHUQE  https://i.ytimg.com/vi/jPGDLCWHUQE/mqdefault.jpg
# 44  7DkbG8xlvEk  https://i.ytimg.com/vi/7DkbG8xlvEk/mqdefault.jpg
# 45  j3iy7UEMrGM  https://i.ytimg.com/vi/j3iy7UEMrGM/mqdefault.jpg
# 46  0Jh173tQM6A  https://i.ytimg.com/vi/0Jh173tQM6A/mqdefault.jpg
# 47  ondEuoxfxso  https://i.ytimg.com/vi/ondEuoxfxso/mqdefault.jpg
# 48  qMvfuziJwRE  https://i.ytimg.com/vi/qMvfuziJwRE/mqdefault.jpg
# 49  jX0ZltFJefw  https://i.ytimg.com/vi/jX0ZltFJefw/mqdefault.jpg

# %%
df.to_csv('chim_videos.csv', index = False)

# %%
## 채널부터 시작해 영상 목록까지 가져오는 함수
def search_datas(query, max_result = 30):
    youtube = use_api()
    
    ## query에 해당하는 채널 이름 찾기
    ## max_result의 갯수 만큼 채널을 찾아 가져옴.
    result  = youtube.search().list(
                q          = query,
                part       = 'snippet',
                maxResults = max_result
            ).execute()
    
    ## youtube api에서 가져온 데이터가 json 데이터에 좀 복잡한 구조로 되어있는데,
    ## 채널 id는 channel_id 변수처럼 가져올 수 있다.
    channel_id = result['items'][0]['id']['channelId']
    playlists  = search_playlists(youtube, channel_id)
    
    return playlists
    
##채널 내 플레이리스트의 id 가져오는 함수
def search_playlists(youtube, id, max_result = 100):
    ## channelId에 해당하는 플레이리스트 찾기
    ## max_result의 갯수 만큼의 플레이리스트를 찾아 가져옴.
    result = youtube.playlists().list(
                channelId  = id,
                part       = 'snippet',
                maxResults = max_result
            ).execute()
    
    ## 플레이리스트 id 저장 
    ids = []
    
    for playlist in result['items']: 
        title = playlist['snippet']['localized']['title']
        if '침착맨 정주행' in title: ids.append(playlist['id'])
    return ids

df = search_datas('침착맨', max_result = 1)
df
# Out:
# ['PLif_jr7pPZAB6YJFfAg8riV6NtIOqez6j',
#  'PLif_jr7pPZABZsONyeNz1JvpAOxPi8FIs',
#  'PLif_jr7pPZADliLF8xwsm7BJHUqq_CUKo',
#  'PLif_jr7pPZADJ2MJ-iHlgLijM6xkCaFlo',
#  'PLif_jr7pPZAD8EJtkFBBctqm5L38JqtGb']

# %% [markdown]
# ## 전체 영상 가져오기
# [[여기 확인해보기]](https://velog.io/@keemsw/%EC%9C%A0%ED%8A%9C%EB%B8%8C-API%EB%A5%BC-%ED%99%9C%EC%9A%A9%ED%95%98%EC%97%AC-%EB%8F%99%EC%98%81%EC%83%81-%EB%A6%AC%EC%8A%A4%ED%8A%B8%EC%97%85-%ED%95%98%EA%B8%B0)

# %%
from collections import namedtuple
import pandas as pd

csv = pd.read_csv('chim_videos.csv')
vid = namedtuple('videos', ['dates', 'titles', 'ids', 'thumbnails'])

datas = zip(*[csv[c] for c in csv.columns])
datas = [vid._make(data) for data in datas]

# %%
datas
# Out:
# [videos(dates='2022-05-22T12:56:52Z', titles='환타로 만든 뱅쇼 vs 쌍화탕으로 만든 모주', ids='0pw5gBIAWQM', thumbnails='https://i.ytimg.com/vi/0pw5gBIAWQM/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='2021년은 어땠나? 2022년은 어떨까?', ids='rwYoIzl5o9U', thumbnails='https://i.ytimg.com/vi/rwYoIzl5o9U/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='치킨계의 냉전시대', ids='-YZ_z_TRBnY', thumbnails='https://i.ytimg.com/vi/-YZ_z_TRBnY/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='90년대 애니 여캐 둘러보기', ids='IcTjuJGoPbQ', thumbnails='https://i.ytimg.com/vi/IcTjuJGoPbQ/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='저가요 거위인데요', ids='bDKA_p8jhSw', thumbnails='https://i.ytimg.com/vi/bDKA_p8jhSw/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='꽁치가처넌의 멸망의 노래!', ids='qMc79yi2N4A', thumbnails='https://i.ytimg.com/vi/qMc79yi2N4A/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles="침착맨과 인기웹툰 '나 혼자만 레벨업' 같이 보기", ids='Z__KMr6QLEQ', thumbnails='https://i.ytimg.com/vi/Z__KMr6QLEQ/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='맞기 싫은 몽둥이 월드컵', ids='V0pNWjWlazo', thumbnails='https://i.ytimg.com/vi/V0pNWjWlazo/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='새해 금연합니다, 현상금 1000만원', ids='yJI9iCKlD9A', thumbnails='https://i.ytimg.com/vi/yJI9iCKlD9A/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='특이한 벌레와 새 이야기', ids='5T_4pnS6nxA', thumbnails='https://i.ytimg.com/vi/5T_4pnS6nxA/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='오랜만에 버거형제', ids='vm0O-Hpjs4g', thumbnails='https://i.ytimg.com/vi/vm0O-Hpjs4g/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='최고의 겨울 간식 월드컵', ids='leOZrOGHj6U', thumbnails='https://i.ytimg.com/vi/leOZrOGHj6U/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='포켓몬의 미싱링크를 그려보자', ids='g9lOemftn5g', thumbnails='https://i.ytimg.com/vi/g9lOemftn5g/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='신생대(新生代)를 알아보자', ids='gsCrrBZQFqU', thumbnails='https://i.ytimg.com/vi/gsCrrBZQFqU/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='2021 침투부상 트로피 직접 만들기', ids='9X6U1rT9A8I', thumbnails='https://i.ytimg.com/vi/9X6U1rT9A8I/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='나라가 허락한 대마커피', ids='AOr439f6bJU', thumbnails='https://i.ytimg.com/vi/AOr439f6bJU/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles="'히어로의 과학' 특강 | 제1부 2021년의 히어로", ids='AsdHKLOM8uQ', thumbnails='https://i.ytimg.com/vi/AsdHKLOM8uQ/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='전무아저씨와 도시락 먹으며 잡담', ids='jQTkB4d_wms', thumbnails='https://i.ytimg.com/vi/jQTkB4d_wms/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles="'히어로의 과학' 특강 | 제2부 하루종일 설명할 수도 있어", ids='cmPAz7k3njs', thumbnails='https://i.ytimg.com/vi/cmPAz7k3njs/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='맵크나이트의 엄청 매운 킹뚜껑 먹방', ids='dz3lctZkn9o', thumbnails='https://i.ytimg.com/vi/dz3lctZkn9o/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='전 직장에 놀러가면 안 되는 이유', ids='VLtv7n38xi4', thumbnails='https://i.ytimg.com/vi/VLtv7n38xi4/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='다낳대 야구선수 vs 스트리머 LoL 대회', ids='m3RvsWliS3w', thumbnails='https://i.ytimg.com/vi/m3RvsWliS3w/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='더 놀라운 이왜진? 월드컵', ids='kOl27s1mgrg', thumbnails='https://i.ytimg.com/vi/kOl27s1mgrg/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='🎙️침터뷰 | 카더가든 편 - 말하는 걸 보면 노래가 상상이 안되는 가수', ids='viPb0y86E4w', thumbnails='https://i.ytimg.com/vi/viPb0y86E4w/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='삼괴권(三壞拳)의 고수를 찾아서', ids='uKej8YD7Rlg', thumbnails='https://i.ytimg.com/vi/uKej8YD7Rlg/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='칭찬양파 vs 비난양파 키우기', ids='4t6x8M4bBvU', thumbnails='https://i.ytimg.com/vi/4t6x8M4bBvU/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles="원피스 '밀짚모자 일당' NEW 구조조정안", ids='HlsL7Aw0ez4', thumbnails='https://i.ytimg.com/vi/HlsL7Aw0ez4/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles="오다 선생님도 틀릴 거 같은 '원피스 3회 지식왕 결정전' 퀴즈", ids='4-koqJzCpwY', thumbnails='https://i.ytimg.com/vi/4-koqJzCpwY/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='침착맨 주호민과 느껴보는 적벽대전', ids='9h7AeWCBhtQ', thumbnails='https://i.ytimg.com/vi/9h7AeWCBhtQ/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='일하면서 침투부 보면 안 되는 이유', ids='kDHSEDAfwL8', thumbnails='https://i.ytimg.com/vi/kDHSEDAfwL8/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='명절에 늦게 온 통천', ids='-dlJP9QTWAM', thumbnails='https://i.ytimg.com/vi/-dlJP9QTWAM/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='비버니가 한 번 더 진화한다면?', ids='1cS4UvhLxwU', thumbnails='https://i.ytimg.com/vi/1cS4UvhLxwU/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='맨유 팬에게 축구선수 카드 팔기', ids='VQsu6Xr25R8', thumbnails='https://i.ytimg.com/vi/VQsu6Xr25R8/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='금연 23일차에 하는 담배 월드컵', ids='hVE_Qc6PjoA', thumbnails='https://i.ytimg.com/vi/hVE_Qc6PjoA/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='2022 설맞이 내기 윷놀이 ~커피부터 한우까지~', ids='AiiRy_6iVB4', thumbnails='https://i.ytimg.com/vi/AiiRy_6iVB4/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='5초 안에 연상되는 3단어를 말하는 보드게임', ids='86h0qmq28ec', thumbnails='https://i.ytimg.com/vi/86h0qmq28ec/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='포켓몬은 도구인가 친구인가', ids='aCwk7SgIJ2U', thumbnails='https://i.ytimg.com/vi/aCwk7SgIJ2U/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='맵크나이트의 킹뚜껑 2차 도전', ids='qXvzGDzMqKU', thumbnails='https://i.ytimg.com/vi/qXvzGDzMqKU/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='시청자가 묻고 침착맨이 답한다', ids='s3LBApU5Brg', thumbnails='https://i.ytimg.com/vi/s3LBApU5Brg/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='원펀데이 간접체험 게임', ids='jia05SIv73M', thumbnails='https://i.ytimg.com/vi/jia05SIv73M/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='단어를 맞혀 구미호를 찾아라', ids='MjT31FNnc8I', thumbnails='https://i.ytimg.com/vi/MjT31FNnc8I/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles="만화게임북 '고기동 大탈출'", ids='WXA1kDzhRw0', thumbnails='https://i.ytimg.com/vi/WXA1kDzhRw0/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='7년 동안 침투부는 얼마나 성장했나', ids='rSKfIJx79Pw', thumbnails='https://i.ytimg.com/vi/rSKfIJx79Pw/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='노딱 설명회는 노딱을 받을까?', ids='jPGDLCWHUQE', thumbnails='https://i.ytimg.com/vi/jPGDLCWHUQE/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='침착맨 팬아트 감상회', ids='7DkbG8xlvEk', thumbnails='https://i.ytimg.com/vi/7DkbG8xlvEk/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='40대 아저씨들의 내기', ids='j3iy7UEMrGM', thumbnails='https://i.ytimg.com/vi/j3iy7UEMrGM/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='침&펄과 무신사 봄 신상 입어보기', ids='0Jh173tQM6A', thumbnails='https://i.ytimg.com/vi/0Jh173tQM6A/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='옛날 로봇이 좋은 이유', ids='ondEuoxfxso', thumbnails='https://i.ytimg.com/vi/ondEuoxfxso/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='괴상한 코믹스 캐릭터 월드컵', ids='qMvfuziJwRE', thumbnails='https://i.ytimg.com/vi/qMvfuziJwRE/mqdefault.jpg'),
#  videos(dates='2022-05-22T12:56:52Z', titles='대콩절 기념 최고의 2인자 월드컵 제1부', ids='jX0ZltFJefw', thumbnails='https://i.ytimg.com/vi/jX0ZltFJefw/mqdefault.jpg')]
